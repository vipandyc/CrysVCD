# %% [markdown]
# Find out which materials to calculate from MP-20 dataset.
#
# A few criterias:
#
# All of these must be true:
# - Binary compound or unary compound
# - Unitcell less or equal than 10 atoms (diamond: 8 per cubic cell)
# - Contain one element lighter or equal than Chroride (mass: 17)
# - If there is a second element, then the second element is lighter or equal than Bromine (mass: 35)

# %%
import pandas as pd
import re

# Define element groups
light_elements = {
    "H", "Li", "Be", "B", "C", "N", "O", "F",
    "Na", "Mg", "Al", "Si", "P", "S", "Cl"
}
heavy_elements = {
    "K", "Ca", "Sc", "Ti", "V", "Cr", "Mn", "Fe",
    "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br"
}
metallic_elements = {
    "Li", "Be", "Na", "Mg", "Al", "K", "Ca", "Sc", "Ti",
    "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga",
    "Ge"
}  # Common metallic elements

# List of illegal formulas to remove
illegal_formulas = {"SF6", "O2", "H2", "HCl", "SiH", "HF", "HC", "HBr", "BrCl", "Br2Cl3", "H4C",\
                    "F2", "H2O", "CO2", "SO2", "N2", }

# Merge the CSV files
df = pd.concat([pd.read_csv(f) for f in ["../MP20_dataset/train.csv", "../MP20_dataset/val.csv",
                                         "../MP20_dataset/test.csv"]], ignore_index=True)
print(f"Total entries before filtering: {len(df)}")

# Function to count unit cell atoms
def get_atom_count(cif):
    match = re.search(r"_cell_formula_units_Z\s+([\d\.]+)", cif)
    if not match:
        return None
    Z = float(match.group(1))

    formula_match = re.search(r"_chemical_formula_sum\s+['\"]?([^'\"]+)['\"]?", cif)
    if not formula_match:
        return None

    formula = formula_match.group(1)
    atom_counts = sum(int(n) if n else 1 for _, n in re.findall(r"([A-Z][a-z]*)(\d*)", formula))
    return Z * atom_counts

# Function to check element criteria (excluding pure metallic compounds and illegal formulas)
def check_elements(row):
    elements_str = row["elements"].strip("[]").replace("'", "").replace('"', "")
    elements = [e.strip() for e in elements_str.split(",")]
    
    pretty_formula = row["pretty_formula"].strip()

    if len(elements) > 2:
        return False  # Only unary or binary compounds allowed

    if pretty_formula in illegal_formulas:
        return False  # Remove known unwanted formulas

    if all(el in metallic_elements for el in elements):
        return False  # Remove pure metallic compounds

    if len(elements) == 1:
        return elements[0] in light_elements  # Unary must be a light element

    # Binary case: either both are light elements, or one light and one heavy
    light_count = sum(el in light_elements for el in elements)
    heavy_count = sum(el in heavy_elements for el in elements)

    return light_count == 2 or (light_count == 1 and heavy_count == 1)

# Apply filters
df["unitcell_atoms"] = df["cif"].apply(get_atom_count)
filtered_df = df[
    (df["unitcell_atoms"] <= 12) & 
    (df.apply(check_elements, axis=1))
]

# Save filtered results
filtered_df.to_csv("filtered.csv", index=False)
filtered_df["pretty_formula"].to_csv("column_data.csv", index=False, header=True)

print(f"Filtered data saved to 'filtered.csv'.")
print(f"Total entries after filtering: {len(filtered_df)}")
print(filtered_df["pretty_formula"])
# Out:
# Total entries before filtering: 45229
# Filtered data saved to 'filtered.csv'.
# Total entries after filtering: 368
# 173        ZnO
# 358        MnS
# 371        FeS
# 880      SiSe2
# 933       CoO2
#          ...
# 44578     LiN3
# 44687     Mn2N
# 44747        C
# 44816      GaN
# 44855     LiCl
# Name: pretty_formula, Length: 368, dtype: object

# %% [markdown]
# Then export to POSCAR

# %%
import pandas as pd
import os
from tqdm import tqdm
from pymatgen.core import Structure
from pymatgen.io.vasp import Poscar

# Read the filtered CSV
df = pd.read_csv("filtered.csv")

# Create output directory
output_dir = "structures_for_kappa"
os.makedirs(output_dir, exist_ok=True)

# Loop through each row and convert to POSCAR
for _, row in tqdm(df.iterrows()):
    mp_id = row["material_id"]  # Get material ID
    cif_str = row["cif"]  # Get CIF string

    try:
        # Convert CIF to pymatgen Structure
        structure = Structure.from_str(cif_str, fmt="cif")

        # Convert Structure to POSCAR
        poscar = Poscar(structure)

        # Save POSCAR file
        poscar_filename = os.path.join(output_dir, f"POSCAR_{mp_id}")
        '''with open(poscar_filename, "w") as f:
            f.write(str(poscar))'''

        #print(f"Saved: {poscar_filename}")

    except Exception as e:
        print(f"Error processing {mp_id}: {e}")

print("All POSCAR files generated successfully!")
# Out:
# 0it [00:00, ?it/s]/home/vipandyc/miniconda3/envs/crygen/lib/python3.12/site-packages/pymatgen/core/structure.py:3087: UserWarning: Issues encountered while parsing CIF: 8 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# 1it [00:00,  9.42it/s]/home/vipandyc/miniconda3/envs/crygen/lib/python3.12/site-packages/pymatgen/core/structure.py:3087: UserWarning: Issues encountered while parsing CIF: 4 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# /home/vipandyc/miniconda3/envs/crygen/lib/python3.12/site-packages/pymatgen/core/structure.py:3087: UserWarning: Issues encountered while parsing CIF: 12 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# 51it [00:00, 288.56it/s]/home/vipandyc/miniconda3/envs/crygen/lib/python3.12/site-packages/pymatgen/core/structure.py:3087: UserWarning: Issues encountered while parsing CIF: 6 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# /home/vipandyc/miniconda3/envs/crygen/lib/python3.12/site-packages/pymatgen/core/structure.py:3087: UserWarning: Issues encountered while parsing CIF: 2 fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   struct = parser.parse_structures(primitive=primitive)[0]
# 368it [00:00, 455.62it/s]
# All POSCAR files generated successfully!

# %%
# !zip -r structures_for_kappa.zip structures_for_kappa/
# !rm -rf structures_for_kappa/
# Out:
#   adding: structures_for_kappa/ (stored 0%)
#   adding: structures_for_kappa/POSCAR_mp-7790 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-27705 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-7583 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mvc-11241 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-1229 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-604884 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-849086 (deflated 76%)
#   adding: structures_for_kappa/POSCAR_mp-30034 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-1226378 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-1180046 (deflated 75%)
#   adding: structures_for_kappa/POSCAR_mp-1080771 (deflated 83%)
#   adding: structures_for_kappa/POSCAR_mp-917 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1205322 (deflated 75%)
#   adding: structures_for_kappa/POSCAR_mp-24084 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-22877 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-23267 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-362 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1094090 (deflated 82%)
#   adding: structures_for_kappa/POSCAR_mp-24161 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1009130 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-28116 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-850131 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-545512 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-28910 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mvc-11598 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-22857 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-1062030 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-23703 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1225186 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-2657 (deflated 80%)
#   adding: structures_for_kappa/POSCAR_mp-1225835 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-34688 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-1185959 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-865 (deflated 83%)
#   adding: structures_for_kappa/POSCAR_mp-570538 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1013526 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-21395 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-505531 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-555908 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-1871 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-1217106 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-849060 (deflated 63%)
#   adding: structures_for_kappa/POSCAR_mp-1018028 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-1072104 (deflated 78%)
#   adding: structures_for_kappa/POSCAR_mp-1522 (deflated 76%)
#   adding: structures_for_kappa/POSCAR_mp-972825 (deflated 76%)
#   adding: structures_for_kappa/POSCAR_mp-1008394 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-20738 (deflated 75%)
#   adding: structures_for_kappa/POSCAR_mp-685145 (deflated 60%)
#   adding: structures_for_kappa/POSCAR_mp-2352 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1013525 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-1114 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-1219182 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-1235877 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-22914 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-1249 (deflated 80%)
#   adding: structures_for_kappa/POSCAR_mp-13150 (deflated 64%)
#   adding: structures_for_kappa/POSCAR_mp-1873 (deflated 78%)
#   adding: structures_for_kappa/POSCAR_mp-753890 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-1575 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-1077045 (deflated 82%)
#   adding: structures_for_kappa/POSCAR_mp-21325 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-1266 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-1602 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1866 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-830 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1279979 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-149 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-1221697 (deflated 76%)
#   adding: structures_for_kappa/POSCAR_mp-463 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-804 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1185148 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-9816 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-944 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-556911 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1147746 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-1367 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-882 (deflated 78%)
#   adding: structures_for_kappa/POSCAR_mp-9973 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-755671 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-755875 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-1185953 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-8282 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-2379 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-25223 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-1179443 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-390 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-990448 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-1018050 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-1915 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-29941 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mvc-14047 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-23289 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-1072956 (deflated 78%)
#   adding: structures_for_kappa/POSCAR_mp-7891 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-9923 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1479 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1008559 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-24726 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-1120739 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-1145 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-1235708 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-14019 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-535 (deflated 82%)
#   adding: structures_for_kappa/POSCAR_mp-1220079 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-1077263 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-567279 (deflated 80%)
#   adding: structures_for_kappa/POSCAR_mp-549706 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-1238899 (deflated 58%)
#   adding: structures_for_kappa/POSCAR_mp-546794 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-569270 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1185942 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-13032 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1064952 (deflated 63%)
#   adding: structures_for_kappa/POSCAR_mp-28233 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-2582 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-754806 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-754064 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-24093 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1986 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-492 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-22787 (deflated 75%)
#   adding: structures_for_kappa/POSCAR_mp-24809 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-1700 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-1901 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-550206 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-8880 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-2172 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-755072 (deflated 78%)
#   adding: structures_for_kappa/POSCAR_mp-8860 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-22631 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-976280 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-10694 (deflated 81%)
#   adding: structures_for_kappa/POSCAR_mp-8882 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-715262 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-648 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-1138 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1076 (deflated 83%)
#   adding: structures_for_kappa/POSCAR_mp-1077503 (deflated 75%)
#   adding: structures_for_kappa/POSCAR_mp-682 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-505622 (deflated 82%)
#   adding: structures_for_kappa/POSCAR_mp-1432 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1235796 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1018040 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-22905 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-704645 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-1077545 (deflated 75%)
#   adding: structures_for_kappa/POSCAR_mp-23214 (deflated 76%)
#   adding: structures_for_kappa/POSCAR_mp-1206425 (deflated 82%)
#   adding: structures_for_kappa/POSCAR_mp-1185301 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-1224796 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-2605 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-6988 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-684904 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-1818 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-1272749 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-1227257 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-7140 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-570259 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-753759 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-1133 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1183691 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-19009 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-22003 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-558852 (deflated 81%)
#   adding: structures_for_kappa/POSCAR_mp-2659 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-1960 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-10118 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1070456 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-1225059 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-937760 (deflated 64%)
#   adding: structures_for_kappa/POSCAR_mp-763 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-568806 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-849059 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-998915 (deflated 78%)
#   adding: structures_for_kappa/POSCAR_mp-1206884 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1206874 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-964 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-696114 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-972828 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-25424 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-2490 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-7590 (deflated 62%)
#   adding: structures_for_kappa/POSCAR_mp-23870 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1225811 (deflated 61%)
#   adding: structures_for_kappa/POSCAR_mp-1315 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-568264 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1008632 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-1120788 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-661 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-23259 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-19079 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-22904 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-1018157 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1173084 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-10734 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-559092 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1065577 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-755413 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-999192 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-2686 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-1221793 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-33031 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-1563 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-2065 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-755263 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-560902 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-631 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-486 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-30999 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-22848 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-644481 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-24237 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-448 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-2536 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-2741 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-557523 (deflated 76%)
#   adding: structures_for_kappa/POSCAR_mp-889 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mvc-13555 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-12910 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-7291 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-23210 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-1001835 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1639 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-507 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-1550 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-19094 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-714885 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-8039 (deflated 81%)
#   adding: structures_for_kappa/POSCAR_mp-13031 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-24719 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1153 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-260 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-973053 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-978534 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-2857 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-555934 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-1226072 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-559798 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-1215 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-20211 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-8372 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-2562 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-2252 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-554340 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-1539213 (deflated 75%)
#   adding: structures_for_kappa/POSCAR_mp-971 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-32686 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-1066400 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-998914 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-1095024 (deflated 83%)
#   adding: structures_for_kappa/POSCAR_mp-1228799 (deflated 62%)
#   adding: structures_for_kappa/POSCAR_mp-1064456 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-7991 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-2156 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-23229 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-862 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-23240 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-2700 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-22916 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-22909 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-361 (deflated 82%)
#   adding: structures_for_kappa/POSCAR_mp-555 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-1009657 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-9969 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-25234 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-169 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-1235059 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1178763 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1476 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-1060435 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1265 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-554462 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-1002114 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1009077 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-246 (deflated 81%)
#   adding: structures_for_kappa/POSCAR_mp-1009733 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-24208 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-27710 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-20318 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-27507 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-1569 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-976404 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-632329 (deflated 63%)
#   adding: structures_for_kappa/POSCAR_mp-547074 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-571096 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-2199 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-642644 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-629015 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-1080834 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1378 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-1007881 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1001581 (deflated 80%)
#   adding: structures_for_kappa/POSCAR_mp-1184046 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-2699 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-1491 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-1185319 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-2133 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-1206441 (deflated 80%)
#   adding: structures_for_kappa/POSCAR_mp-493 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-8062 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-560588 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-1040425 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-8881 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-1101754 (deflated 86%)
#   adding: structures_for_kappa/POSCAR_mp-19177 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-632413 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1206157 (deflated 78%)
#   adding: structures_for_kappa/POSCAR_mp-1591 (deflated 75%)
#   adding: structures_for_kappa/POSCAR_mp-23710 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-20027 (deflated 78%)
#   adding: structures_for_kappa/POSCAR_mp-1018027 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-684668 (deflated 78%)
#   adding: structures_for_kappa/POSCAR_mp-690760 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-24728 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1205309 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-422 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-760381 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1071032 (deflated 80%)
#   adding: structures_for_kappa/POSCAR_mp-1094056 (deflated 83%)
#   adding: structures_for_kappa/POSCAR_mp-1025170 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-984 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1081 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-642822 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1217157 (deflated 76%)
#   adding: structures_for_kappa/POSCAR_mp-1541 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-2251 (deflated 74%)
#   adding: structures_for_kappa/POSCAR_mp-545796 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-2542 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-1018804 (deflated 78%)
#   adding: structures_for_kappa/POSCAR_mp-1297083 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-19006 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-2807 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-2482 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-8352 (deflated 76%)
#   adding: structures_for_kappa/POSCAR_mp-7582 (deflated 72%)
#   adding: structures_for_kappa/POSCAR_mp-1022 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-1078123 (deflated 80%)
#   adding: structures_for_kappa/POSCAR_mp-634859 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-374 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-27396 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-2286 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-24287 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-8937 (deflated 67%)
#   adding: structures_for_kappa/POSCAR_mp-22142 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-2291 (deflated 69%)
#   adding: structures_for_kappa/POSCAR_mp-570744 (deflated 83%)
#   adding: structures_for_kappa/POSCAR_mp-10695 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-1692 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-1010 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-828 (deflated 80%)
#   adding: structures_for_kappa/POSCAR_mp-30139 (deflated 71%)
#   adding: structures_for_kappa/POSCAR_mp-9561 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-556324 (deflated 77%)
#   adding: structures_for_kappa/POSCAR_mp-1672 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-9889 (deflated 70%)
#   adding: structures_for_kappa/POSCAR_mp-558110 (deflated 68%)
#   adding: structures_for_kappa/POSCAR_mp-470 (deflated 79%)
#   adding: structures_for_kappa/POSCAR_mp-10760 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1783 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-1225993 (deflated 75%)
#   adding: structures_for_kappa/POSCAR_mp-15809 (deflated 73%)
#   adding: structures_for_kappa/POSCAR_mp-1778 (deflated 66%)
#   adding: structures_for_kappa/POSCAR_mp-1238787 (deflated 80%)
#   adding: structures_for_kappa/POSCAR_mp-23193 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-22862 (deflated 65%)
#   adding: structures_for_kappa/POSCAR_mp-1225654 (deflated 63%)
#   adding: structures_for_kappa/POSCAR_mp-976802 (deflated 80%)
